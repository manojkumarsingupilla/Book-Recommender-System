# %%
import pandas as pd

books = pd.read_csv("notebooks/Books.csv")

print(books.columns)   # to see available columns
print(books.head(5))   # to see sample rows
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# ...

# %%
print(books[books['Book-Title'].str.contains("Hobbit", case=False, na=False)])
# Out:
#               ISBN                                         Book-Title  \
# 1763    0395177111       The Hobbit (Leatherette Collector's Edition)
# 2785    0618002219                The Hobbit: or There and Back Again
# 3354    0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 3356    0345272579                                         The Hobbit
# 5367    0618162216        The Hobbit (Young Adult edition, Sis cover)
# 6253    0345318587                                         The Hobbit
# 6866    0345340426               The Hobbit and The Lord of the Rings
# 14107   8845906884                             Lo Hobbit / The Hobbit
# 15650   2253049417                                   Bilbo, Le Hobbit
# 15677   0618260307                The Hobbit: Or There and Back Again
# 16351   0345296044                The Hobbit: Or There and Back Again
# 26487   1594130051                                         The Hobbit
# ...

# %%
import pickle
book_pivot = pickle.load(open("artifacts/serialized_objects/book_pivot.pkl", "rb"))
hobbit_editions = [title for title in book_pivot.index if "hobbit" in title.lower()]
print(hobbit_editions)
